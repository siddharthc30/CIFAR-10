# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharthc30/CIFAR-10/blob/main/CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0291d182-ab38-410d-a986-92d94fe13914" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0291d182-ab38-410d-a986-92d94fe13914">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"siddharthc30","key":"09b5501351cdb4f0a0ad4b15b33d26ec"}'}

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# kaggle.json

# %%
# !kaggle competitions download -c cifar-10
# Out:
# ...
#  97% 593M/610M [00:05<00:00, 146MB/s]
# 100% 610M/610M [00:05<00:00, 124MB/s]
# ...
#  97% 102M/105M [00:00<00:00, 125MB/s]
# 100% 105M/105M [00:00<00:00, 141MB/s]
# ...
#   0% 0.00/575k [00:00<?, ?B/s]
# 100% 575k/575k [00:00<00:00, 130MB/s]
# ...
#   0% 0.00/655k [00:00<?, ?B/s]
# 100% 655k/655k [00:00<00:00, 217MB/s]

# %%
# !ls
# Out:
# kaggle.json  sampleSubmission.csv.zip  train.7z
# sample_data  test.7z		       trainLabels.csv

# %%
# !mkdir train

# %%
# !mv train.7z ./train

# %%
# !mkdir test

# %%
# !mv test.7z ./test

# %%
# %cd ./train
# Out:
# /content/train

# %%
# !pwd
# Out:
# /content/train

# %%
!7z e train.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 109723070 bytes (105 MiB)
#
# Extracting archive: train.7z
# --
# Path = train.7z
# Type = 7z
# Physical Size = 109723070
# Headers Size = 294768
# Method = LZMA:26
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 50000
# Size:       112650757
# Compressed: 109723070

# %%
# %cd ..
# Out:
# /content

# %%
import os
import pandas as pd

# %%
def read_csv_labels(fname):
    with open(fname, 'r') as f:
        lines = f.readlines()[1:]
    tokens = [l.rstrip().split(',') for l in lines]
    return dict(((name, label) for name, label in tokens))

labels = read_csv_labels('trainLabels.csv')
print('# training examples:', len(labels))
print('# classes:', len(set(labels.values())))
# Out:
# # training examples: 50000
# # classes: 10
